# %%
print("Hello python")
print(5+8)
print(90-10)
print(4*7)
print(7/2)
print(7//2)
5+int("5")
# Out:
# Hello python
# 13
# 80
# 28
# 3.5
# 3
# 10

# %%
import math

chinese = 78
chinese += 5
chinese *= 10

# chinese 開平方根
value = round(math.sqrt(chinese),ndigits=2)
value
# Out:
# 28.81

# %%
weight=72
height=1.75**2
bmi=round(weight/height,2)
bmi
# Out:
# 23.51
